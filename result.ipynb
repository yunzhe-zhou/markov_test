# %%
import numpy as np

def print_result(string,if_return=False):
    pvalue=np.load(string+".npy",allow_pickle=True)
    if not if_return:
        print(np.sum(pvalue<0.05)/len(pvalue))  
    
    if if_return:
        return np.sum(pvalue<0.05)/len(pvalue)

# %%
print_result("mdn_var_run_cv_T_500_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_500_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_500_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_500_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_500_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
# Out:
# 0.952
# 0.258
# 0.052
# 0.042
# 0.056

# %%
print_result("mdn_var_run_cv_T_1000_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1000_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1000_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1000_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1000_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
# Out:
# 1.0
# 0.856
# 0.042
# 0.044
# 0.044

# %%
print_result("mdn_var_run_cv_T_1500_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1500_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1500_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1500_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_var_run_cv_T_1500_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
# Out:
# 1.0
# 0.992
# 0.06
# 0.058
# 0.048

# %%
print_result("mdn_shred_run_cv_T_500_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_500_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_500_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_500_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_500_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
# Out:
# 0.614
# 0.16
# 0.062
# 0.04
# 0.06

# %%
print_result("mdn_shred_run_cv_T_1000_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1000_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1000_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1000_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1000_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
# Out:
# 0.998
# 0.716
# 0.056
# 0.036
# 0.056

# %%
print_result("mdn_shred_run_cv_T_1500_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1500_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1500_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1500_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
print_result("mdn_shred_run_cv_T_1500_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000")
# Out:
# 1.0
# 0.976
# 0.066
# 0.048
# 0.034

# %%
print_result("mdn_arch_run_cv_T_1000_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_arch_run_cv_T_1000_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_arch_run_cv_T_1000_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_arch_run_cv_T_1000_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_arch_run_cv_T_1000_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
# Out:
# 0.368
# 0.332
# 0.064
# 0.042
# 0.064

# %%
print_result("mdn_march_run_cv_T_1500_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_1500_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_1500_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_1500_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_1500_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
# Out:
# 0.648
# 0.642
# 0.044
# 0.05
# 0.058

# %%
print_result("mdn_march_run_cv_T_2000_test_lag_1_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_2000_test_lag_2_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_2000_test_lag_3_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_2000_test_lag_4_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
print_result("mdn_march_run_cv_T_2000_test_lag_5_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000")
# Out:
# 0.846
# 0.838
# 0.058
# 0.054
# 0.064

# %%
pvalue=np.load("mdn_real1_run_cv_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000"+".npy",allow_pickle=True)
print(pvalue)
# Out:
# [0.11  0.187 0.371 0.591 0.454 0.282 0.186 0.049 0.206 0.117 0.78  0.027]

# %%
pvalue=np.load("mdn_real2_run_cv_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000"+".npy",allow_pickle=True)
print(pvalue)
# Out:
# [0.394 0.365 0.259 0.467 0.706 0.14  0.288 0.437 0.312 0.168 0.355 0.47 ]

# %%
pvalue=np.load("mdn_real3_run_cv_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000"+".npy",allow_pickle=True)
print(pvalue)
# Out:
# [0.    0.01  0.03  0.24  0.243 0.421 0.436 0.485 0.36  0.338 0.485 0.411]

# %%
import matplotlib.pyplot as plt 
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,8))
axes = ax.flatten()
x = np.array(["1","2","3","4","5"])
major_ticks_y=np.linspace(0,1,11)
minor_ticks_y=np.linspace(0,1,21)

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_2_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l1=axes[0].plot(x, y_ls,color="limegreen",linestyle='-',marker="o", markersize=7, label='L=2')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l2=axes[0].plot(x, y_ls,color="deepskyblue",linestyle='-',marker="o", markersize=7, label='L=3')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_4_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l3=axes[0].plot(x, y_ls,color="lightsalmon",linestyle='-',marker="o", markersize=7, label='L=4')


axes[0].axhline(y=0.05, color='red', linestyle='--')
axes[0].set_title(r"Different Choices of L", fontsize=14)
axes[0].legend(loc="upper right")


y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_250_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l1=axes[1].plot(x, y_ls,color="limegreen",linestyle='-',marker="o", markersize=7, label='B=250')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_500_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l2=axes[1].plot(x, y_ls,color="deepskyblue",linestyle='-',marker="o", markersize=7, label='B=500')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l3=axes[1].plot(x, y_ls,color="lightsalmon",linestyle='-',marker="o", markersize=7, label='B=1000')


axes[1].axhline(y=0.05, color='red', linestyle='--')
axes[1].set_title(r"Different Choices of B", fontsize=14)
axes[1].legend(loc="upper right")

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_5_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l1=axes[2].plot(x, y_ls,color="limegreen",linestyle='-',marker="o", markersize=7, label='Q=5')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l2=axes[2].plot(x, y_ls,color="deepskyblue",linestyle='-',marker="o", markersize=7, label='Q=10')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_15_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l3=axes[2].plot(x, y_ls,color="lightsalmon",linestyle='-',marker="o", markersize=7, label='Q=15')


axes[2].axhline(y=0.05, color='red', linestyle='--')
axes[2].set_title(r"Different Choices of Q", fontsize=14)
axes[2].legend(loc="upper right")


y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_20_n_iter_6000",True)
    y_ls.append(y)
l1=axes[3].plot(x, y_ls,color="limegreen",linestyle='-',marker="o", markersize=7, label='U=20')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_40_n_iter_6000",True)
    y_ls.append(y)
l2=axes[3].plot(x, y_ls,color="deepskyblue",linestyle='-',marker="o", markersize=7, label='U=40')

y_ls = []
for i in range(1,6,1):
    y = print_result("mdn_var_run_cv_T_500_test_lag_"+str(i)+"_L_3_B_1000_M_100_Q_10_lr_0.005_num_h_60_n_iter_6000",True)
    y_ls.append(y)
l3=axes[3].plot(x, y_ls,color="lightsalmon",linestyle='-',marker="o", markersize=7, label='U=60')


axes[3].axhline(y=0.05, color='red', linestyle='--')
axes[3].set_title(r"Different Number of Hidden Units (U)", fontsize=14)
axes[3].legend(loc="upper right")



for i in range(4):
    axes[i].set_yticks(major_ticks_y)
    axes[i].set_yticks(minor_ticks_y,minor=True)
    axes[i].grid(which="major",alpha=1)
    axes[i].grid(which="minor",alpha=1,linestyle ="dashdot")
    axes[i].set_xlabel('Lag', fontsize=12)
    axes[i].set_ylabel('Rejection rates', fontsize=12)
    
plt.tight_layout(pad=1)  
plt.show()
fig.savefig('../sensitivity.svg', format = "svg", dpi=1000)
